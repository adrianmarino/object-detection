# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
from IPython.display import JSON
import random
sys.path.append('..')

from lib.dataset.pascal_voc.pascal_voc_dataset import PascalVOCDataset
from lib.dataset.plot import plot_samples_count_by_class, plot_missing_samples_by_class, missing_samples_count_by_class
from lib.json_utils import to_json
from lib.config import Config
from lib.dataset.plot import show_sample

# %%
cfg = Config('../config.yml')

# %%
train_dataset = PascalVOCDataset('../dataset/train/samples')
test_dataset = PascalVOCDataset('../dataset/test/samples')

# %%
train_samples = list(train_dataset.samples())
test_samples = list(test_dataset.samples())

# %% [markdown]
# Samples count:

# %%
print(f'Train: {len(train_samples)}')
print(f'Test: {len(test_samples)}')
# Out:
# Train: 374546
# Test: 500

# %%
# JSON(to_json(train_samples))

# %%
expected_classes = set(cfg.property('labels'))
train_dataset_classes = train_dataset.labels()
test_dataset_classes = test_dataset.labels()

# %% [markdown]
# Dataset have the correct class names?

# %%
len(train_dataset_classes), len(expected_classes)
# Out:
# (52, 52)

# %%
len(test_dataset_classes), len(expected_classes)
# Out:
# (52, 52)

# %%
assert train_dataset_classes == expected_classes, "Wrong train dataset classes!"

# %%
# assert test_dataset_classes == expected_classes, "Wrong test dataset classes!"

# %%
test_dataset_classes - expected_classes
# Out:
# set()

# %%
expected_classes - test_dataset_classes
# Out:
# set()

# %% [markdown]
# Show train sampels count by class:

# %%
plot_samples_count_by_class(train_dataset)

# %% [markdown]
# How many samples is required to **balance** samples by class to 15 accours?

# %%
plot_missing_samples_by_class(train_dataset)

# %%
missing_samples_count_by_class(train_dataset)
# Out:
#    Class  Missing  Count
# 0     8d     1068  22711
# 1     Js      955  22824
# 2     Ks      912  22867
# 3     Qs      902  22877
# 4     As      859  22920
# 5     Ah      859  22920
# 6     Qd      823  22956
# 7     6s      820  22959
# 8     9c      806  22973
# 9     5h      788  22991
# 10    Ac      764  23015
# 11   10d      751  23028
# 12    8h      687  23092
# 13    2s      683  23096
# 14    5s      663  23116
# 15    Jc      658  23121
# 16    4s      633  23146
# 17   10c      597  23182
# 18    Kc      597  23182
# 19    4d      596  23183
# 20    3c      592  23187
# 21    7c      559  23220
# 22    3s      558  23221
# 23    7h      521  23258
# 24    Qh      517  23262
# 25    4c      516  23263
# 26    2h      510  23269
# 27    7d      508  23271
# 28    9s      504  23275
# 29    2d      503  23276
# 30    5c      489  23290
# 31    5d      487  23292
# 32    Jh      444  23335
# 33    4h      432  23347
# 34    8c      431  23348
# 35    3d      428  23351
# 36   10s      414  23365
# 37    7s      389  23390
# 38    6c      385  23394
# 39    Kd      383  23396
# 40    Ad      346  23433
# 41    6h      325  23454
# 42    Kh      314  23465
# 43    Qc      263  23516
# 44    6d      205  23574
# 45    9d      183  23596
# 46    9h      182  23597
# 47   10h      160  23619
# 48    3h      116  23663
# 49    2c      108  23671
# 50    8s       61  23718
# 51    Jd        0  23779

# %% [markdown]
# Show test sampels count by class:

# %%
plot_samples_count_by_class(test_dataset)

# %% [markdown]
# How many samples is required to **balance** samples by class to 15 accours?

# %%
plot_missing_samples_by_class(test_dataset)

# %%
missing_samples_count_by_class(test_dataset)
# Out:
#    Class  Missing  Count
# 0     3d       30     17
# 1     6c       29     18
# 2     Ac       28     19
# 3     5c       27     20
# 4     8c       25     22
# 5     2d       24     23
# 6     Kd       24     23
# 7    10h       24     23
# 8     Kh       23     24
# 9     5h       21     26
# 10    Qd       21     26
# 11    6s       21     26
# 12    2s       21     26
# 13    9h       21     26
# 14    2c       19     28
# 15    Ks       19     28
# 16    9s       19     28
# 17    Qc       19     28
# 18    6h       18     29
# 19    Qs       17     30
# 20    7s       17     30
# 21    3c       17     30
# 22    As       16     31
# 23    Kc       16     31
# 24   10c       16     31
# 25    Jh       16     31
# 26    3s       16     31
# 27    Js       16     31
# 28    4d       15     32
# 29    8h       15     32
# 30    7d       15     32
# 31    Jc       15     32
# 32    7c       13     34
# 33    4s       13     34
# 34    Ah       12     35
# 35    4h       12     35
# 36    6d       12     35
# 37    Ad       12     35
# 38    5d       11     36
# 39    5s       11     36
# 40   10d        9     38
# 41   10s        9     38
# 42    8s        9     38
# 43    9d        9     38
# 44    3h        8     39
# 45    2h        8     39
# 46    Jd        7     40
# 47    4c        7     40
# 48    9c        7     40
# 49    8d        6     41
# 50    Qh        6     41
# 51    7h        0     47

# %%
show_sample(random.choice(train_samples))

# %%
show_sample(random.choice(test_samples))
